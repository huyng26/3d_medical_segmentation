# %% [markdown]
# # Phase 1 — Data Exploration
#
# Covers:
# - Voxel spacing and volume shape statistics for BTCV and MSD
# - Intensity histograms (raw HU and post-clip / normalised)
# - Label distribution plots (per-class voxel counts)
# - Slice previews (axial / sagittal / coronal)

# %%
# Standard imports — add others as needed
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## 1. Dataset paths

# %%
BTCV_RAW   = Path("../data/raw/btcv")
MSD_LIVER  = Path("../data/raw/msd/Task03_Liver")
MSD_SPLEEN = Path("../data/raw/msd/Task09_Spleen")

# %% [markdown]
# ## 2. Voxel spacing & shape survey
#
# TODO: iterate over NIfTI files, print/collect spacing and shape.

# %%
# TODO

# %% [markdown]
# ## 3. Intensity histograms
#
# TODO: plot HU histograms for a sample of volumes; mark clip bounds [-175, 250].

# %%
# TODO

# %% [markdown]
# ## 4. Label distribution
#
# TODO: per-class voxel count bar chart for BTCV (14 classes) and MSD tasks.

# %%
# TODO

# %% [markdown]
# ## 5. Slice previews with label overlay
#
# TODO: show axial / sagittal / coronal slices for one volume per dataset with masks.

# %%
# TODO
